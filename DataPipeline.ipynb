# %%
# !pip install requests

# %%
import requests
import time

# %%
data = requests.get('https://jsonplaceholder.typicode.com/users')

# %%
data = data.json()

# %%
def data_pipeline(data,jwt_token,url):
    count = 1
    headers = {

    'Authorization': 'Bearer {}'.format(jwt_token),
    'Content-Type': 'application/json'
    }
   
    for data in data:
        print('Storing data {}'.format(count))
        time.sleep(2)
        response = requests.post(url,json={
            'name':data['name'],'username':data['username'],
            'email':data['email'], 'address':{
              'street':data['address']['street'],
                'suite':data['address']['suite'],
                'city':data['address']['city'],
                'zip_code':data['address']['zipcode'],
                'geo_location':{'lat':data['address']['geo']['lat'],'lng':data['address']['geo']['lng']},
            },
            'phone':data['phone'], 'website':f"https://www.{data['website']}.com",'company':{
              'name':data['company']['name'], 'catchPhrase':data['company']['catchPhrase'],'bs':data['company']['bs']  
            },
        },headers=headers)
        if response.status_code == 201:
            print(f'data : {count} completed')
            count = count+1
        else:
            print('Error:', str(response))
            break

# %%
url = ' http://127.0.0.1:8000/app/user/create'
token = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNzE4ODgyNjU5LCJpYXQiOjE3MTg4NjU1MTcsImp0aSI6IjkxNzgyYzA3NjY0MTQ1Nzg4MjE3MjU5MmFlNmE1MjE4IiwidXNlcl9pZCI6MX0.y-7XcopgV4pIbtrmERhUek9Ujakcv-zIUu9Z92MaVGc'

# %%
data_pipeline(data,token,url)
# Out:
# Storing data 1
# data : 1 completed
# Storing data 2
# data : 2 completed
# Storing data 3
# data : 3 completed
# Storing data 4
# data : 4 completed
# Storing data 5
# data : 5 completed
# Storing data 6
# data : 6 completed
# Storing data 7
# data : 7 completed
# Storing data 8
# data : 8 completed
# Storing data 9
# data : 9 completed
# Storing data 10
# data : 10 completed

# %%
data
# Out:
# [{'id': 1,
#   'name': 'Leanne Graham',
#   'username': 'Bret',
#   'email': 'Sincere@april.biz',
#   'address': {'street': 'Kulas Light',
#    'suite': 'Apt. 556',
#    'city': 'Gwenborough',
#    'zipcode': '92998-3874',
#    'geo': {'lat': '-37.3159', 'lng': '81.1496'}},
#   'phone': '1-770-736-8031 x56442',
#   'website': 'hildegard.org',
#   'company': {'name': 'Romaguera-Crona',
#    'catchPhrase': 'Multi-layered client-server neural-net',
#    'bs': 'harness real-time e-markets'}},
#  {'id': 2,
#   'name': 'Ervin Howell',
#   'username': 'Antonette',
#   'email': 'Shanna@melissa.tv',
#   'address': {'street': 'Victor Plains',
#    'suite': 'Suite 879',
#    'city': 'Wisokyburgh',
#    'zipcode': '90566-7771',
#    'geo': {'lat': '-43.9509', 'lng': '-34.4618'}},
#   'phone': '010-692-6593 x09125',
#   'website': 'anastasia.net',
#   'company': {'name': 'Deckow-Crist',
#    'catchPhrase': 'Proactive didactic contingency',
#    'bs': 'synergize scalable supply-chains'}},
# ...

# %%
cycle = 1
for i in range(1,100):
    print('Cycle Process {} -------------------'.format(cycle))
    time.sleep(2)
    data_pipeline(data,token,url) 
    time.sleep(1)
    print('Cycle Process {} completed ---------------------'.format(cycle) )
    cycle = cycle+1
# Out:
# Cycle Process 1 -------------------
# Storing data 1
# data : 1 completed
# Storing data 2
# data : 2 completed
# Storing data 3
# data : 3 completed
# Storing data 4
# data : 4 completed
# Storing data 5
# data : 5 completed
# Storing data 6
# data : 6 completed
# Storing data 7
# data : 7 completed
# Storing data 8
# data : 8 completed
# Storing data 9
# data : 9 completed
# Storing data 10
# data : 10 completed
# Cycle Process 1 completed ---------------------
# Cycle Process 2 -------------------
# Storing data 1
# data : 1 completed
# Storing data 2
# data : 2 completed
# Storing data 3
# data : 3 completed
# Storing data 4
# data : 4 completed
# Storing data 5
# data : 5 completed
# Storing data 6
# data : 6 completed
# Storing data 7
# data : 7 completed
# Storing data 8
# data : 8 completed
# Storing data 9
# data : 9 completed
# Storing data 10
# data : 10 completed
# Cycle Process 2 completed ---------------------
# Cycle Process 3 -------------------
# Storing data 1
# ...
